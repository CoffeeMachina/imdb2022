# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=2.0)
sns.set_palette("magma")
import pylab
pylab.rcParams['figure.figsize'] = (15, 9)
plt.style.use('dark_background')
import warnings
warnings.filterwarnings('ignore')

from datetime import datetime
today=datetime.today()
today_file=str(today.year) +'-' + str(today.month) + '-'+ str(today.day)
today_graph=datetime.strptime(today_file, '%Y-%m-%d').strftime('%B %d, %Y')

import os
imdb_path = os.environ.get('DB_IMDB_MX')
df = pd.read_csv(imdb_path,index_col='Date Rated',parse_dates = True)

# %%
movie = df[df['Title Type'] == 'movie']

# %%
movie
# Out:
#                  Const  Your Rating                    Title  \
# Date Rated
# 2021-02-26  tt10016180            4        The Little Things
# 2011-03-19   tt1010048            9      Slumdog Millionaire
# 2011-03-19   tt1013753            8                     Milk
# 2011-01-22   tt1017460            7                   Splice
# 2020-04-28   tt1028528            7              Death Proof
# ...                ...          ...                      ...
# 2015-02-01   tt0978762            8             Mary and Max
# 2021-05-31   tt0993840            2         Army of the Dead
# 2015-01-04   tt0993846            9  The Wolf of Wall Street
# 2011-11-15   tt0099685            8               Goodfellas
# 2011-09-16   tt0999913            3               Straw Dogs
#
#                                                URL Title Type  IMDb Rating  \
# Date Rated
# 2021-02-26  https://www.imdb.com/title/tt10016180/      movie          6.3
# 2011-03-19   https://www.imdb.com/title/tt1010048/      movie          8.0
# 2011-03-19   https://www.imdb.com/title/tt1013753/      movie          7.5
# 2011-01-22   https://www.imdb.com/title/tt1017460/      movie          5.7
# 2020-04-28   https://www.imdb.com/title/tt1028528/      movie          7.0
# ...                                            ...        ...          ...
# 2015-02-01   https://www.imdb.com/title/tt0978762/      movie          8.1
# 2021-05-31   https://www.imdb.com/title/tt0993840/      movie          5.9
# 2015-01-04   https://www.imdb.com/title/tt0993846/      movie          8.2
# 2011-11-15   https://www.imdb.com/title/tt0099685/      movie          8.7
# 2011-09-16   https://www.imdb.com/title/tt0999913/      movie          5.8
#
#             Runtime (mins)  Year                                   Genres  \
# Date Rated
# 2021-02-26           128.0  2021                   Crime, Drama, Thriller
# 2011-03-19           120.0  2008                           Drama, Romance
# 2011-03-19           128.0  2008                         Biography, Drama
# 2011-01-22           104.0  2009                    Drama, Horror, Sci-Fi
# 2020-04-28           127.0  2007              Action, Adventure, Thriller
# ...                    ...   ...                                      ...
# 2015-02-01            92.0  2009         Animation, Comedy, Drama, Family
# 2021-05-31           148.0  2021  Action, Crime, Horror, Sci-Fi, Thriller
# 2015-01-04           180.0  2013                  Biography, Crime, Drama
# 2011-11-15           146.0  1990                  Biography, Crime, Drama
# 2011-09-16           110.0  2011                  Action, Drama, Thriller
#
#             Num Votes Release Date                     Directors
# Date Rated
# 2021-02-26      59290   2021-01-28              John Lee Hancock
# 2011-03-19     808664   2008-08-30  Loveleen Tandan, Danny Boyle
# 2011-03-19     166667   2008-10-28                  Gus Van Sant
# 2011-01-22      94471   2009-10-06               Vincenzo Natali
# 2020-04-28     273210   2007-05-22             Quentin Tarantino
# ...               ...          ...                           ...
# 2015-02-01     167272   2009-01-15                   Adam Elliot
# 2021-05-31      94615   2021-05-14                   Zack Snyder
# 2015-01-04    1226324   2013-12-09               Martin Scorsese
# 2011-11-15    1044242   1990-09-09               Martin Scorsese
# 2011-09-16      33160   2011-09-16                     Rod Lurie
#
# [484 rows x 12 columns]

# %%
movie.resample('Y').mean()
# Out:
#             Your Rating  IMDb Rating  Runtime (mins)         Year  \
# Date Rated
# 2010-12-31     7.555556     7.088889      112.888889  2006.111111
# 2011-12-31     6.841379     7.326207      117.020690  2005.144828
# 2012-12-31     6.483871     7.225806      116.032258  2007.903226
# 2013-12-31     7.000000     6.852174      113.869565  2010.434783
# 2014-12-31     6.840000     7.352000      113.960000  2009.440000
# 2015-12-31     7.064516     7.558065      120.822581  2010.225806
# 2016-12-31     6.500000     7.250000      114.970588  2010.647059
# 2017-12-31     6.243243     6.981081      117.162162  2013.243243
# 2018-12-31     7.485714     7.208571      117.114286  2010.600000
# 2019-12-31     6.485714     6.968571      122.428571  2017.571429
# 2020-12-31     6.823529     7.273529      116.382353  2013.411765
# 2021-12-31     5.785714     7.057143      123.142857  2016.142857
#
#                 Num Votes
# Date Rated
# 2010-12-31  308559.777778
# 2011-12-31  445415.889655
# 2012-12-31  379619.322581
# 2013-12-31  272415.869565
# 2014-12-31  355422.280000
# 2015-12-31  440768.951613
# 2016-12-31  355097.411765
# 2017-12-31  271308.054054
# 2018-12-31  331174.885714
# 2019-12-31  195206.628571
# 2020-12-31  248367.823529
# 2021-12-31  130404.142857

# %%
movie.resample('Y').sum()
# Out:
#             Your Rating  IMDb Rating  Runtime (mins)    Year  Num Votes
# Date Rated
# 2010-12-31           68         63.8          1016.0   18055    2777038
# 2011-12-31          992       1062.3         16968.0  290746   64585304
# 2012-12-31          201        224.0          3597.0   62245   11768199
# 2013-12-31          161        157.6          2619.0   46240    6265565
# 2014-12-31          171        183.8          2849.0   50236    8885557
# 2015-12-31          438        468.6          7491.0  124634   27327675
# 2016-12-31          221        246.5          3909.0   68362   12073312
# 2017-12-31          231        258.3          4335.0   74490   10038398
# 2018-12-31          262        252.3          4099.0   70371   11591121
# 2019-12-31          227        243.9          4285.0   70615    6832232
# 2020-12-31          232        247.3          3957.0   68456    8444506
# 2021-12-31           81         98.8          1724.0   28226    1825658

# %%
year_total_mins=movie.resample('Y').sum()['Runtime (mins)']

# %% [markdown]
# # <font color='lime'> FINISHED GRAPH:

# %%
fig=plt.figure(figsize=(20,20))

g=sns.barplot(x=year_total_mins.index.year, y=year_total_mins/60,edgecolor='slateblue')
g.set_title(f"MintyXenomorph's Movie Hours Per Year \nAs of {today_graph}\n",size=55,color='lime')
g.set_xlabel('Year',size=34,color='lime')
g.set_ylabel('Hours',size=34,color='lime')
g.grid(axis='y',color='red')

plt.setp(g.patches, linewidth=5) #change bar width

#color the axis and tick labels
g.spines['bottom'].set_color('#fc6afa')
g.spines['right'].set_color('#fc6afa')
g.spines['top'].set_color('#fc6afa')
g.spines['left'].set_color('#fc6afa')

g.tick_params(axis='x', colors='#fc6afa')
g.tick_params(axis='y', colors='#fc6afa')
#color the axis and tick labels
g.spines['left'].set_linewidth(3)
g.spines['right'].set_linewidth(3)
g.spines['bottom'].set_linewidth(3)
g.spines['top'].set_linewidth(3)


# Hours per Year Text Above
for p in g.patches:
    g.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 20), 
                   textcoords = 'offset points',color='lime')

    # Inside bar: movie Count
# movie.resample('Y').count()['Title']
movie_count = movie.resample('Y').count()['Title']
for p,movie_countx in zip(g.patches,movie_count):
    g.annotate(format(str(movie_countx)+'\n films'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, -30), 
                   textcoords = 'offset points',color='#e0073a')
# plt.savefig(f"{today_file}_ratings.png")
